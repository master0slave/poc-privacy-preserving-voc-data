# %% [markdown]
# # Import data

# %%
import pandas as pd
df = pd.read_csv('../data/raw/voc-data-202401-202404.csv', encoding='utf-8', on_bad_lines='skip')
df.head()
# Out:
#   หมายเลขเสียง ประเภทสารสนเทศ   วันที่บันทึกข้อมูล                สายงาน  \
# 0    V-6700214    ความต้องการ  29/03/2024 00:08 น.  สายงานการไฟฟ้า ภาค 4
# 1   C-59717760    ความคาดหวัง  28/03/2024 22:23 น.  สายงานการไฟฟ้า ภาค 4
# 2   C-59716002    ความคาดหวัง  28/03/2024 22:20 น.  สายงานการไฟฟ้า ภาค 2
# 3    V-6700213    ความต้องการ  28/03/2024 17:10 น.  สายงานการไฟฟ้า ภาค 3
# 4   C-59713262    ความคาดหวัง  28/03/2024 15:44 น.  สายงานการไฟฟ้า ภาค 1
#
#                               ฝ่าย/เขต  \
# 0  การไฟฟ้าเขต 2 (นครศรีธรรมราช) ภาค 4
# 1       การไฟฟ้าเขต 1 (เพชรบุรี) ภาค 4
# 2    การไฟฟ้าเขต 2 (อุบลราชธานี) ภาค 2
# 3         การไฟฟ้าเขต 2 (ชลบุรี) ภาค 3
# 4             การไฟฟ้าเขต3(ลพบุรี)ภาค1
#
#                                         กอง/การไฟฟ้า ช่องทางการรับฟังเสียง  \
# 0  K11101 : การไฟฟ้าส่วนภูมิภาคอำเภอถลาง ชั้น2 จั...               Digital
# 1  J13201 : การไฟฟ้าส่วนภูมิภาคสาขาอำเภอสวี จังหว...              Physical
# ...

# %%
df.dropna(subset=['รายละเอียดเสียง'], inplace=True)
text_df = df[['หมายเลขเสียง','รายละเอียดเสียง']].copy()

# %%
text_df.rename(columns={'หมายเลขเสียง':'voc_id','รายละเอียดเสียง': 'text'}, inplace=True)

# %%
text_df.head()
# Out:
#        voc_id                                               text
# 0   V-6700214   ระบบแสงสว่างยังใช้งานได้ แต่แสงสว่างลดลง เครื...
# 1  C-59717760  แนะนำ กฟอ.สวี จังหวัดชุมพร  เรื่องไฟฟ้าตกบ่อย ...
# 2  C-59716002  แนะนำ กฟอ.อาจสามารถ จังหวัด ร้อยเอ็ด เรื่องไฟฟ...
# 3   V-6700213  เบื้องต้นได้แจ้งเจ้าหน้าที่การไฟฟ้ามาทำการตรวจ...
# 4  C-59713262  แนะนำ กฟจ.ลพบุรี เรื่องไฟฟ้าตกบ่อย บ้านเลขที่ ...

# %% [markdown]
# # Define function to doing text nane entity recognition

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForTokenClassification
from pythainlp.tokenize import word_tokenize # pip install pythainlp
import torch

# %%
text_df.loc[1]['text']
# Out:
# 'แนะนำ กฟอ.สวี จังหวัดชุมพร  เรื่องไฟฟ้าตกบ่อย บ้านเลขที่ 253 ม.7 บ.น้ำชล ต.ทุ่งระยะ อ.สวี จ.ชุมพร ผู้ใช้ไฟฟ้าแจ้งว่าในพื้นที่มีกระแสไฟฟ้าตกบ่อย ซึ่งทางผู้ใช้ไฟฟ้าแจ้งว่าได้เคยมีการแนะนำเข้าไปแล้วเมื่อปี 2566 แต่ปัจจุบันก็ยังมีไฟฟ้าตกในพื้นที่ ผู้ใช้ไฟแจ้งว่าบ้านอยู่ห่างจากหม้อแปลงไม่เกิน 300 เมตร แต่ไฟมาไม่ถึง 200 วัตต์ จากเหตุการณ์ที่เกิดขึ้นเกรงว่าอุปกรณ์เครื่องใช้ไฟฟ้าจะได้รับความเสียหาย จึงต้องการให้ กฟอ.สวี และหน่วยงานที่เกี่ยวข้องเข้าดำเนินการตรวจสอบปรับปรุงแก้ไขระบบคุณภาพไฟฟ้าในพื้นที่ให้ดียิ่งขึ้น//ผู้ใช้ไฟฟ้าคุณปิยะวัฒน์  หมายเลขติดต่อกลับ 0840807317'

# %%
def get_ner_tag(sentence):
    name = "Porameht/wangchanberta-thainer-corpus-v2-2"
    tokenizer = AutoTokenizer.from_pretrained(name)
    model = AutoModelForTokenClassification.from_pretrained(name)
    cut = word_tokenize(sentence.replace(" ", "<_>"))
    inputs = tokenizer(cut, is_split_into_words=True, return_tensors="pt")
    ids = inputs["input_ids"]
    mask = inputs["attention_mask"]
    outputs = model(ids, attention_mask=mask)
    logits = outputs[0]
    predictions = torch.argmax(logits, dim=2)
    predicted_token_class = [model.config.id2label[t.item()] for t in predictions[0]]

    def fix_span_error(words, ner):
        _new_tag = []
        for i, j in zip(words, ner):
            i = tokenizer.decode(i)
            if i.isspace() and j.startswith("B-"):
                j = "O"
            if i == '' or i == '<s>' or i == '</s>':
                continue
            if i == "<_>":
                i = " "
            _new_tag.append((i, j))
        return _new_tag

    ner_tag = fix_span_error(inputs['input_ids'][0], predicted_token_class)
    return ner_tag

# %%
text = text_df.loc[1]['text']
ner_tag = get_ner_tag(text)

# %%
ner_tag
# Out:
# [('แนะนํา', 'O'),
#  (' ', 'B-ORGANIZATION'),
#  ('ก', 'B-ORGANIZATION'),
#  ('ฟ', 'I-ORGANIZATION'),
#  ('อ', 'I-ORGANIZATION'),
#  ('.', 'I-ORGANIZATION'),
#  ('ส', 'I-ORGANIZATION'),
#  ('วี', 'I-ORGANIZATION'),
#  (' ', 'B-LOCATION'),
#  ('จังหวัด', 'B-LOCATION'),
#  ('ชุมพร', 'I-LOCATION'),
#  (' ', 'O'),
#  (' ', 'O'),
#  ('เรื่อง', 'O'),
#  ('ไฟฟ้า', 'O'),
#  ('ตก', 'O'),
#  ('บ่อย', 'O'),
#  (' ', 'O'),
#  ('บ้าน', 'O'),
#  ('เลขที่', 'O'),
#  (' ', 'B-LOCATION'),
#  ('25', 'I-LOCATION'),
#  ('3', 'I-LOCATION'),
#  (' ', 'B-LOCATION'),
#  ('ม', 'I-LOCATION'),
#  ('.', 'I-LOCATION'),
#  ('7', 'I-LOCATION'),
#  (' ', 'B-LOCATION'),
#  ('บ', 'B-LOCATION'),
#  ('.', 'I-LOCATION'),
#  ('น้ํา', 'I-LOCATION'),
#  ('ชล', 'I-LOCATION'),
#  (' ', 'B-LOCATION'),
#  ('ต', 'B-LOCATION'),
#  ('.', 'I-LOCATION'),
#  ('ทุ่ง', 'I-LOCATION'),
#  ('ระยะ', 'I-LOCATION'),
#  (' ', 'B-LOCATION'),
#  ('อ', 'B-LOCATION'),
#  ('.', 'I-LOCATION'),
#  ('ส', 'I-LOCATION'),
#  ('วี', 'I-LOCATION'),
# ...

# %%
def ner_nasking(ner_tag:list):
    masked = ""
    current_entity = None 

    for token, tag in ner_tag:
        if tag == 'O':
            masked += token
            current_entity = None
        else:
            entity = tag.split('-')[1]
            if tag.startswith('B-') or current_entity != entity:
                masked += f"[{entity}]"
                current_entity = entity
            elif tag.startswith('I-') and current_entity == entity:
                continue
            else:
                current_entity = None
                masked += token

    return masked.strip()

marked_text = ner_nasking(ner_tag)
print(marked_text)
# Out:
# แนะนํา[ORGANIZATION][ORGANIZATION][LOCATION][LOCATION]  เรื่องไฟฟ้าตกบ่อย บ้านเลขที่[LOCATION][LOCATION][LOCATION][LOCATION][LOCATION][LOCATION][LOCATION][LOCATION][LOCATION][LOCATION] ผู้ใช้ไฟฟ้าแจ้งว่าในพื้นที่มีกระแสไฟฟ้าตกบ่อย ซึ่งทางผู้ใช้ไฟฟ้าแจ้งว่าได้เคยมีการแนะนําเข้าไปแล้วเมื่อปี[DATE] แต่ปัจจุบันก็ยังมีไฟฟ้าตกในพื้นที่ ผู้ใช้ไฟแจ้งว่าบ้านอยู่ห่างจากหม้อแปลงไม่เกิน [LEN] แต่ไฟมาไม่ถึง 200 วัตต์ จากเหตุการณ์ที่เกิดขึ้นเกรงว่าอุปกรณ์เครื่องใช้ไฟฟ้าจะได้รับความเสียหาย จึงต้องการให้[ORGANIZATION][ORGANIZATION] และหน่วยงานที่เกี่ยวข้องเข้าดําเนินการตรวจสอบปรับปรุงแก้ไขระบบคุณภาพไฟฟ้าในพื้นที่ให้ดียิ่งขึ้น//ผู้ใช้ไฟฟ้า[PERSON]  หมายเลขติดต่อกลับ [PHONE]17

# %%
import re

def remove_redundant_tags(text):
    # ลบ tag ซ้ำติดกัน เช่น [ORG][ORG] เหลือ [ORG]
    return re.sub(r'(\[[A-Z]+\])\1+', r'\1', text)

# %%
text_head_10 = text_df.head(10).copy()

# %%
for i, row in text_head_10.iterrows():
    ner_tag = get_ner_tag(row['text'])
    marked_text = ner_nasking(ner_tag)
    cleaned_text = remove_redundant_tags(marked_text)
    text_head_10.at[i, 'marked_text'] = cleaned_text
    
text_head_10
# Out:
#        voc_id                                               text  \
# 0   V-6700214   ระบบแสงสว่างยังใช้งานได้ แต่แสงสว่างลดลง เครื...
# 1  C-59717760  แนะนำ กฟอ.สวี จังหวัดชุมพร  เรื่องไฟฟ้าตกบ่อย ...
# 2  C-59716002  แนะนำ กฟอ.อาจสามารถ จังหวัด ร้อยเอ็ด เรื่องไฟฟ...
# 3   V-6700213  เบื้องต้นได้แจ้งเจ้าหน้าที่การไฟฟ้ามาทำการตรวจ...
# 4  C-59713262  แนะนำ กฟจ.ลพบุรี เรื่องไฟฟ้าตกบ่อย บ้านเลขที่ ...
# 5   V-6700212   ระบบแสงสว่างยังใช้งานได้ แต่แสงสว่างลดลง พัดล...
# 6   V-6700211  ปัญหาไฟตก ไฟกระชากเสี้ยววินาที ทำให้อุปกรณ์ไฟฟ...
# 7  C-59712540  แนะนำ กฟอ.ลำลูกกา จังหวัด ปทุมธานี เรื่องไฟฟ้า...
# 8  C-59712056  แนะนำ กฟย.นบพิตำ จังหวัดนครศรีธรรมราช เรื่องไฟ...
# 9  C-59711629  แนะนำ กฟอ.กันตัง  จังหวัดตรัง  เรื่องไฟฟ้าตกบ่...
#
#                                          marked_text
# 0  ระบบแสงสว่างยังใช้งานได้ แต่แสงสว่างลดลง เครื่...
# 1  แนะนํา[ORGANIZATION][LOCATION]  เรื่องไฟฟ้าตกบ...
# 2  แนะนํา[ORGANIZATION][LOCATION] เรื่องไฟฟ้าดับบ...
# ...

# %%
text_head_10.loc[9]['marked_text']
# Out:
# 'แนะนํา[ORGANIZATION][LOCATION]  เรื่องไฟฟ้าตกบ่อย [LOCATION]  ผู้ใช้ไฟฟ้าแจ้งว่าในพื้นที่มีกระแสไฟฟ้าตกบ่อยตกทุกวัน  [ORGANIZATION]ฟ.เป็นร้านขายยาจําเป็นต้องใช้แอร์ จากเหตุการณ์ที่เกิดขึ้นเกรงว่าอุปกรณ์เครื่องใช้ไฟฟ้าจะได้รับความเสียหาย จึงต้องการให้[ORGANIZATION] และหน่วยงานที่เกี่ยวข้องเข้าดําเนินการตรวจสอบปรับปรุงแก้ไขระบบคุณภาพไฟฟ้าในพื้นที่ให้ดียิ่งขึ้น//ผู้ใช้ไฟฟ้า[PERSON] หมายเลขติดต่อกลับ [PHONE]59'

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
def summarize_issue(masked_text):
    system_prompt = """คุณคือผู้ช่วยวิเคราะห์ VOC ที่เน้นหาประเด็นปัญหาเชิงเนื้อหาแบบกระชับและเข้าใจง่ายในโทนภาษาที่เป็นกันเองเหมือนพูดกับผู้บริหาร"""
    user_prompt = f"""จากข้อความที่ผ่านการปกปิดข้อมูลส่วนบุคคลดังนี้:\n\n{masked_text}\n\nช่วยสรุปประเด็นปัญหาหลักที่เกิดขึ้นให้เข้าใจง่าย"""

    response = client.chat.completions.create(
        model="gpt-4o-mini-2024-07-18",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0.1,
        max_tokens=1024,
    )
    return response.choices[0].message.content.strip()

def sentiment_score(summary_text):
    user_prompt = f"""จากข้อความนี้:\n\n{summary_text}\n\nช่วยให้คะแนนความพึงพอใจในช่วง -5 (ไม่พอใจอย่างรุนแรง) ถึง +5 (พึงพอใจมาก) พร้อมสรุปสั้น ๆ ว่าทำไมถึงได้คะแนนนั้น"""

    response = client.chat.completions.create(
        model="gpt-4o-mini-2024-07-18",
        messages=[
            {"role": "system", "content": "คุณคือผู้ช่วยให้คะแนนความพึงพอใจจากข้อความร้องเรียน"},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0.2,
        max_tokens=512
    )
    return response.choices[0].message.content.strip()

# %%
# %%time
for i, row in text_head_10.iterrows():
    masked_text = row['marked_text']
    summary = summarize_issue(masked_text)
    sentiment = sentiment_score(summary)
    text_head_10.at[i, 'summary'] = summary
    text_head_10.at[i, 'sentiment'] = sentiment
text_head_10
# Out:
# CPU times: user 147 ms, sys: 63.3 ms, total: 211 ms
# Wall time: 1min 17s
#        voc_id                                               text  \
# 0   V-6700214   ระบบแสงสว่างยังใช้งานได้ แต่แสงสว่างลดลง เครื...
# 1  C-59717760  แนะนำ กฟอ.สวี จังหวัดชุมพร  เรื่องไฟฟ้าตกบ่อย ...
# 2  C-59716002  แนะนำ กฟอ.อาจสามารถ จังหวัด ร้อยเอ็ด เรื่องไฟฟ...
# 3   V-6700213  เบื้องต้นได้แจ้งเจ้าหน้าที่การไฟฟ้ามาทำการตรวจ...
# 4  C-59713262  แนะนำ กฟจ.ลพบุรี เรื่องไฟฟ้าตกบ่อย บ้านเลขที่ ...
# 5   V-6700212   ระบบแสงสว่างยังใช้งานได้ แต่แสงสว่างลดลง พัดล...
# 6   V-6700211  ปัญหาไฟตก ไฟกระชากเสี้ยววินาที ทำให้อุปกรณ์ไฟฟ...
# 7  C-59712540  แนะนำ กฟอ.ลำลูกกา จังหวัด ปทุมธานี เรื่องไฟฟ้า...
# 8  C-59712056  แนะนำ กฟย.นบพิตำ จังหวัดนครศรีธรรมราช เรื่องไฟ...
# 9  C-59711629  แนะนำ กฟอ.กันตัง  จังหวัดตรัง  เรื่องไฟฟ้าตกบ่...
#
#                                          marked_text  \
# 0  ระบบแสงสว่างยังใช้งานได้ แต่แสงสว่างลดลง เครื่...
# 1  แนะนํา[ORGANIZATION][LOCATION]  เรื่องไฟฟ้าตกบ...
# ...

# %%
text_head_10.to_csv('../data/processed/voc_data_marked_text.csv', index=False, encoding='utf-8')

# %%
text_head_10.to_excel('../data/processed/voc_data_marked_text.xlsx', index=False)
